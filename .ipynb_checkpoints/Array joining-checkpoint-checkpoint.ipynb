# %% [markdown]
# # ARRAY JOINING:
#
# In NumPy, array joining means combining two or more arrays into one array.
# Common methods are:
#
# concatenate()
# stack()
# vstack()
# hstack()
# using transpose() with joining

# %% [markdown]
# # 1. concatenate()
#
# Joins arrays along an existing axis.

# %%
np.concatenate((arr1, arr2), axis=0)

# %%
# Example 1: 1D Array
import numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])

result = np.concatenate((a,b))

print(result)
# Out:
# [1 2 3 4 5 6]

# %%
# Example 2: 2D Array Row-wise
a = np.array([[1,2],
              [3,4]])

b = np.array([[5,6],
              [7,8]])

result = np.concatenate((a,b), axis=0)

print(result)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
# Example 3: 2D Array Column-wise
result = np.concatenate((a,b), axis=1)

print(result)
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %% [markdown]
# # 2.Using concatenate() with transpose()
#
# Sometimes arrays cannot join because dimensions do not match.
# We use transpose to fix shape problems.

# %%
a = np.array([[1,2,3]])
b = np.array([[4,5,6]])

# transpose b
b = b.T

result = np.concatenate((a.T, b), axis=1)

print(result)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]

# %% [markdown]
# # 3.vstack() (Vertical Stack)
#
# Stacks arrays vertically (top to bottom).

# %%
concatenate(axis=0)

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

result = np.vstack((a,b))

print(result)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# # 4.hstack() (Horizontal Stack)
#
# Stacks arrays horizontally (side by side).

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

result = np.hstack((a,b))

print(result)
# Out:
# [1 2 3 4 5 6]

# %%
a = np.array([[1,2],
              [3,4]])

b = np.array([[5,6],
              [7,8]])

result = np.hstack((a,b))

print(result)
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]

# %% [markdown]
# # Difference Between vstack() and hstack()
#
# Function	   Meaning	          Direction
# vstack()	Vertical stack	    Top → Bottom
# hstack()	Horizontal stack	Left → Right

# %%
Important Rule

For joining arrays:

 1.Rows must match for horizontal joining
 2.Columns must match for vertical joining

# %%
# Quick Memory Trick
Function	Easy Meaning 

concatenate()	   General joining
vstack()	       Join vertically
hstack()	       Join horizontally
transpose()	       Swap rows & columns

# %% [markdown]
# # ARRAY SPLIT
#
# In NumPy, splitting means dividing one array into multiple smaller arrays.

# %% [markdown]
# # 1. split()
#
# Splits an array into equal parts.

# %%
# Syntax
np.split(array, sections)

# %%
import numpy as np

a = np.array([1,2,3,4,5,6])

result = np.split(a, 3)

print(result)

# %%
# Error Example
a = np.array([1,2,3,4,5])

np.split(a, 3)

# %% [markdown]
# # 2. array_split()
#
# Works like split() but allows unequal division.

# %%
a = np.array([1,2,3,4,5])

result = np.array_split(a, 3)

print(result)

# %%
#  Difference Between split() and array_split()
Function	          Equal Division Required?
split()	                       Yes
array_split()	                No

# %% [markdown]
# # 3. vsplit() (Vertical Split)
#
# Splits arrays vertically (row-wise).
#
# Works only for 2D or higher arrays.

# %%
a = np.array([[1,2],
              [3,4],
              [5,6],
              [7,8]])

result = np.vsplit(a, 2)

print(result)

# %% [markdown]
# # 4. hsplit() (Horizontal Split)
#
# Splits arrays horizontally (column-wise).

# %%
a = np.array([[1,2,3,4],
              [5,6,7,8]])

result = np.hsplit(a, 2)

print(result)

# %%
# Important Rules
Function	        Split Direction

split()	            General split
array_split()	    Unequal split allowed
vsplit()	        Row-wise split
hsplit()	        Column-wise split

# %% [markdown]
# # Matrix multiplication

# %%
Used to multiply two matrices.

#Rule:
Number of columns in first matrix = number of rows in second matrix.

# %%
import numpy as np

a = np.array([[1, 2],
              [3, 4]])

b = np.array([[5, 6],
              [7, 8]])

print(a @ b)
# Out:
# [[19 22]
#  [43 50]]

# %% [markdown]
# # Determinant

# %%
Special value of square matrix.

# Formula
∣A∣=ad−bc

# %%
print(np.linalg.det(a))
# Out:
# -2.0000000000000004

# %%
#Important: 
If determinant = 0

➡ inverse does not exist.

# %% [markdown]
# # Inverse Matrix

# %%
Inverse works like reciprocal.

A×A−1=I

# %%
print(np.linalg.inv(a))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
print(a @ np.linalg.inv(a))
# Out:
# [[1.0000000e+00 0.0000000e+00]
#  [8.8817842e-16 1.0000000e+00]]

# %%
# Full Combined Example

import numpy as np

a = np.array([[1,2],
              [3,4]])

b = np.array([[5,6],
              [7,8]])

# Matrix multiplication
print("Multiplication:")
print(a @ b)

# Determinant
print("\nDeterminant:")
print(np.linalg.det(a))

# Inverse
print("\nInverse:")
print(np.linalg.inv(a))

# Horizontal joining
print("\nHstack:")
print(np.hstack((a,b)))

# Vertical joining
print("\nVstack:")
print(np.vstack((a,b)))
# Out:
# Multiplication:
# [[19 22]
#  [43 50]]
#
# Determinant:
# -2.0000000000000004
#
# Inverse:
# [[-2.   1. ]
#  [ 1.5 -0.5]]
#
# Hstack:
# [[1 2 5 6]
#  [3 4 7 8]]
#
# Vstack:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
# Difference Between Matrix Operations & Joining

#     Topic	                                          Purpose
Matrix multiplication	                 Mathematical multiplication
Determinant	                             Check invertibility
Inverse	                                 Reverse matrix multiplication
concatenate	                             Combine arrays
hstack	                                 Join columns
vstack	                                 Join rows
